# %% [markdown]
# **1) PRE-PROCESSING**
#
# ---

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import random

# Graphics Libs
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 14, 8

# Feature extraction Libs
import requests
from urllib.parse import urlparse, urlsplit
import tldextract

# %%
data = pd.read_csv('datasets/malicious_urls.csv')
data.describe()
# Out:
#                                                       url    type
# count                                              663191  663191
# unique                                             653040       5
# top     http://style.org.hc360.com/css/detail/mysite/s...  benign
# freq                                                  180  428103

# %%
# Removing duplicates
data = data.drop_duplicates(subset='url')
data.describe()
# Out:
#                      url    type
# count             653040  653040
# unique            653040       5
# top     br-icloud.com.br  benign
# freq                   1  428080

# %%
data
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 663186    http://archive.salisburyjournal.co.uk/2001/3/7/        spam
# 663187  http://astore.amazon.co.uk/allezvinsfrenchr/de...        spam
# 663188  http://archive.thisischeshire.co.uk/2000/1/14/...        spam
# 663189  http://applerugs.co.uk/rugs/product_info.php?p...        spam
# 663190  http://allgirltogaparty.co.uk/gallery2/main.ph...        spam
#
# [653040 rows x 2 columns]

# %%
count = data.type.value_counts()
bar_labels = [count.index[i].capitalize()+' (n. ' + str(count[i]) + ')' for i in range(len(count.index))]
bars = plt.bar(count.index, height=count, label=bar_labels, color=['#8fce00', '#0092ff', '#ff8200', '#ff1100', '#ffcd34'])

for rect in bars:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f} ({height/len(data)*100:.2f}%)', ha='center', va='bottom')

plt.xlabel('LABELS', labelpad=20)
plt.ylabel('COUNT', labelpad=20)
plt.title('EXPLORING DATASET')
plt.legend()
plt.show()

# %%
benign = count[0]
malicious = len(data) - benign
bar_labels = ['Benign (n.'+str(benign)+')', 'Malicious (n.'+str(malicious)+')']
bars = plt.bar(['benign', 'malicious'], height=[benign, malicious], label=bar_labels, color=['#8fce00', '#ff1100'])

for rect in bars:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f} ({height/len(data)*100:.2f}%)', ha='center', va='bottom')

plt.xlabel('CLASSES', labelpad=20)
plt.ylabel('COUNT', labelpad=20)
plt.title('EXPLORING DATASET')
plt.legend()
plt.show()

# %%
benign_urls = data[data['type'] == 'benign']
defacement_urls = data[data['type'] == 'defacement']
phishing_urls = data[data['type'] == 'phishing']
malware_urls = data[data['type'] == 'malware']
spam_urls = data[data['type'] == 'spam']

benign_urls_sample = random.sample(list(benign_urls.index), 10000)
defacement_urls_sample = random.sample(list(defacement_urls.index), 2500)
phishing_urls_sample = random.sample(list(phishing_urls.index), 2500)
malware_urls_sample = random.sample(list(malware_urls.index), 2500)
spam_urls_sample = random.sample(list(spam_urls.index), 2500)

selected_indexes = benign_urls_sample + defacement_urls_sample + phishing_urls_sample + malware_urls_sample + spam_urls_sample
random.shuffle(selected_indexes)
data_sampled = data.loc[selected_indexes]
data_sampled = data_sampled.reset_index(drop=True)

# %%
data_sampled.describe()
# Out:
#                                       url    type
# count                               20000   20000
# unique                              20000       5
# top     http://42.237.17.163:52267/Mozi.m  benign
# freq                                    1   10000

# %%
count = data_sampled.type.value_counts()
bar_labels = [count.index[i].capitalize()+' (n. ' + str(count[i]) + ')' for i in range(len(count.index))]
bars = plt.bar(count.index, height=count, label=bar_labels, color=['#8fce00', '#0092ff', '#ff8200', '#ff1100', '#ffcd34'])

for rect in bars:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f} ({height/len(data_sampled)*100:.2f}%)', ha='center', va='bottom')

plt.xlabel('LABELS', labelpad=20)
plt.ylabel('COUNT', labelpad=20)
plt.title('BALANCED AND SAMPLED DATASET')
plt.legend()
plt.show()

# %%
benign = count[0]
malicious = len(data_sampled) - benign
bar_labels = ['Benign (n.'+str(benign)+')', 'Malicious (n.'+str(malicious)+')']
bars = plt.bar(['benign', 'malicious'], height=[benign, malicious], label=bar_labels, color=['#8fce00', '#ff1100'])

for rect in bars:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f} ({height/len(data_sampled)*100:.2f}%)', ha='center', va='bottom')

plt.xlabel('CLASSES', labelpad=20)
plt.ylabel('COUNT', labelpad=20)
plt.title('BALANCED AND SAMPLED DATASET')
plt.show()

# %%
# file_path = 'datasets/urls_sampled.csv'
# data_sampled.to_csv(file_path, index=False)
# data = pd.read_csv(file_path)
# data.describe()

# %% [markdown]
# **2) FEATURES ENGINEERING**
#
# ---

# %%
#
# Number of character '.' in URL
# Return: numeric
#
def count_dots(url: str):
    return url.count('.')


#
# Number of subdomain levels
# Return: numeric
#
def count_subdomains(url: str):
    subdomain = tldextract.extract(url).subdomain
    return len(subdomain.split('.')) if len(subdomain) != 0 else 0


#
# The depth of URL
# Return: numeric
#
def get_path_level(url: str):
    path = urlsplit(url).path
    path = path[1:] if len(path) > 0 and path[0] == '/' else path
    path = path[:-1] if len(path) > 0 and path[-1] == '/' else path
    return len(path.split('/')) if len(path) > 0 else 0


#
# The length of URL
# Return: numeric
#
def get_len(url: str):
    return len(url)


#
# Number of the dash character '-' in URL
# Return: numeric
#
def count_dash(url: str):
    return url.count('-')


#
# There exists a character '@' in URL
# Return: boolean
#
def check_at_symbol(url: str):
    return '@' in url


#
# There exists a character '~' in URL
# Return: boolean
#
def check_tilde_symbol(url: str):
    return '~' in url


#
# Number of the underscore character '_' in URL
# Return: numeric
#
def count_underscore(url: str):
    return url.count('_')


#
# Number of the percent character '%' in URL
# Return: numeric
#
def count_percent(url: str):
    return url.count('%')


#
# Number of the query components
# Return: numeric
#
def count_query_components(url: str):
    query_components = urlparse(url).query.split("&") if len(urlparse(url).query) > 0 else ''
    return len(query_components)


#
# Number of the ampersand character '&' in URL
# Return: numeric
#
def count_ampersand(url: str):
    return url.count('&')


#
# Number of the hash character '#' in URL
# Return: numeric
#
def count_hash(url: str):
    return url.count('#')


#
# Number of the numeric character
# Return: numeric
#
def count_digits(url: str):
    return sum(c.isdigit() for c in url)


#
# Check if there exists a HTTPS in website URL
# Return: boolean
#
def check_Https(url: str):
    try:
        req = requests.get(url, timeout=1).url
        return req.startswith('https')
    except Exception as e:
        return False


#
# Check if the IP address is used in the hostname of the website URL
# Return: boolean
#
def check_IP_address(url: str):
    return not bool(sum(not c.isdigit() and c != '.' for c in tldextract.extract(url).domain))


#
# Check if TLD is used as a part of the subdomain in website URL
# Return: boolean
#
def check_tld_in_subdomain(url: str):
    res = tldextract.extract(url)
    return res.domain in res.subdomain


#
# Check if TLD is used in the link of website URL
# Return: boolean
#
def check_tld_in_path(url: str):
    return tldextract.extract(url).domain in urlsplit(url).path


#
# Check if HTTPS is disordered in the hostname of website URL
# Return: boolean
#
def check_https_in_hostname(url: str):
    return 'https' in urlsplit(url).netloc


#
# Length of hostname
# Return: numeric
#
def get_hostname_length(url: str):
    return len(urlsplit(url).netloc)


#
# Length of the link path
# Return: numeric
#
def get_path_length(url: str):
    return len(urlparse(url).path)


#
# Length of the query string
# Return: numeric
#
def get_query_length(url):
    return len(urlparse(url).query)


#
# There exists a slash '//' in the link path
# Return: boolean
#
def check_double_slash_in_path(url: str):
    return '//' in urlparse(url).path


#
# Compute the lexical features by URL
# Return: Pandas.Series
#
def get_lexical_features(url, label):
    if not url.startswith(('http://', 'https://', 'ftp://')):
        url = 'http://' + url
    return [
        url,
        count_dots(url),
        count_subdomains(url),
        get_path_level(url),
        get_len(url),
        count_dash(url),
        check_at_symbol(url),
        check_tilde_symbol(url),
        count_underscore(url),
        count_percent(url),
        count_query_components(url),
        count_ampersand(url),
        count_hash(url),
        count_digits(url),
        check_Https(url),
        check_IP_address(url),
        check_tld_in_subdomain(url),
        check_tld_in_path(url),
        check_https_in_hostname(url),
        get_hostname_length(url),
        get_path_length(url),
        get_query_length(url),
        check_double_slash_in_path(url),
        label
    ]

# %%
data_features = pd.DataFrame({
    'url':[],
    'numDots':[],
    'subdomainLevel':[],
    'pathLevel':[],
    'urlLength':[],
    'numDash':[], 
    'atSymbol':[],
    'tildeSymbol':[],
    'numUnderscore':[],
    'numPercent':[],
    'numQueryComponents':[],
    'numApersand':[],          
    'numHash':[],
    'numDigits':[],
    'https':[],
    'ipAddress':[], 
    'domainInSubdomains':[],
    'domainInPaths':[],
    'httpsInHostname':[],
    'hostnameLength':[],
    'pathLength':[],
    'queryLength':[],
    'doubleSlash':[],
    'type': []
})

# %%
# for i in range(len(data)):
#     url = data.loc[i, 'url']
#     label = data.loc[i, 'type']
#     if (i % 500 == 0):
#         print('Rows processed: ',i)
#     try:
#         data_features.loc[i] = get_lexical_features(url, label)
#     except Exception as e:
#         print('>>>>>>> EXCEPTION: ',e)
#         print('>>>>>>> EXCEPTION URL: ',url)
#         print('>>>>>>> EXCEPTION INDEX: ',i)
#         continue
# data_features.to_csv('/content/urls_with_features.csv', index = False)

# %% [markdown]
# **2) EXPLORATIVE DATA ANALYSIS**
#
# ---

# %%
data = pd.read_csv('datasets/urls_with_features.csv')
data.describe()
# Out:
#             numDots  subdomainLevel     pathLevel     urlLength       numDash  \
# count  20000.000000    20000.000000  20000.000000  20000.000000  20000.000000
# mean       2.482300        0.491650      2.169350     70.553750      1.289450
# std        1.498532        0.908775      1.548383     71.897412      2.689336
# min        0.000000        0.000000      0.000000     13.000000      0.000000
# 25%        1.000000        0.000000      1.000000     38.000000      0.000000
# 50%        2.000000        0.000000      2.000000     53.000000      0.000000
# 75%        3.000000        1.000000      3.000000     83.000000      1.000000
# max       25.000000       18.000000     18.000000   1424.000000     39.000000
#
#        numUnderscore    numPercent  numQueryComponents  numApersand  \
# count    20000.00000  20000.000000        20000.000000  20000.00000
# mean         0.48425      0.365150            0.668000      0.45590
# std          1.51399      3.837832            1.563745      1.32153
# min          0.00000      0.000000            0.000000      0.00000
# 25%          0.00000      0.000000            0.000000      0.00000
# 50%          0.00000      0.000000            0.000000      0.00000
# 75%          0.00000      0.000000            0.000000      0.00000
# max         20.00000    147.000000           28.000000     27.00000
#
#             numHash     numDigits  hostnameLength    pathLength   queryLength
# count  20000.000000  20000.000000    20000.000000  20000.000000  20000.000000
# mean       0.000650      7.918400       17.517150     27.930800     17.603400
# std        0.029148     15.195482       10.205705     26.701628     67.855277
# min        0.000000      0.000000        4.000000      0.000000      0.000000
# 25%        0.000000      0.000000       12.000000     10.000000      0.000000
# 50%        0.000000      4.000000       16.000000     21.000000      0.000000
# 75%        0.000000     10.000000       20.000000     37.000000      0.000000
# max        2.000000    332.000000      244.000000    755.000000   1388.000000

# %%
# Null values check
data.isnull().any()
# Out:
# url                   False
# numDots               False
# subdomainLevel        False
# pathLevel             False
# urlLength             False
# numDash               False
# atSymbol              False
# tildeSymbol           False
# numUnderscore         False
# numPercent            False
# numQueryComponents    False
# numApersand           False
# numHash               False
# numDigits             False
# https                 False
# ipAddress             False
# domainInSubdomains    False
# domainInPaths         False
# httpsInHostname       False
# hostnameLength        False
# pathLength            False
# queryLength           False
# doubleSlash           False
# type                  False
# dtype: bool

# %%
safe = data[data['type'] == 'benign']
unsafe = data[data['type'] != 'benign']

# Numerical features
labels_x1 = ['numDots', 'subdomainLevel', 'pathLevel', 'numDash', 'numUnderscore', 'numPercent', 'numQueryComponents', 'numApersand', 'numHash']
labels_x2 = ['urlLength', 'numDigits', 'hostnameLength', 'pathLength', 'queryLength']
# Boolean features
labels_x3 = ['atSymbol', 'tildeSymbol', 'https', 'ipAddress', 'domainInSubdomains', 'domainInPaths', 'httpsInHostname', 'doubleSlash']

features_to_plot1 = {'Safe': [], 'Unsafe': []}
features_to_plot2 = {'Safe': [], 'Unsafe': []}
features_to_plot3 = {'Safe': [], 'Unsafe': []}

for i in labels_x1:
    features_to_plot1['Safe'].append(safe.loc[:, i].mean())
    features_to_plot1['Unsafe'].append(unsafe.loc[:, i].mean())

for i in labels_x2:
    features_to_plot2['Safe'].append(safe.loc[:, i].mean())
    features_to_plot2['Unsafe'].append(unsafe.loc[:, i].mean())

for i in labels_x3:
    features_to_plot3['Safe'].append(safe.loc[:, i].sum())
    features_to_plot3['Unsafe'].append(unsafe.loc[:, i].sum())

x1 = np.arange(len(labels_x1))  # the label locations
x2 = np.arange(len(labels_x2))  # the label locations
x3 = np.arange(len(labels_x3))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ((ax1), (ax2), (ax3)) = plt.subplots(3, 1, figsize=(18, 21))

for attribute, measurement in features_to_plot1.items():
    offset = width * multiplier
    rects = ax1.bar(x1 + offset, [round(i,3) for i in measurement], width, label = attribute, color = ['#8fce00' if attribute == 'Safe' else '#ff1100'])
    ax1.bar_label(rects, padding = 3)
    multiplier += 1
ax1.set_ylabel('Mean values')
ax1.set_title('Numerical features')
ax1.set_xticks(x1 + (width / 2), labels_x1)
ax1.legend(loc = 'upper right')

for attribute, measurement in features_to_plot2.items():
    offset = width * multiplier
    rects = ax2.bar(x2 + offset, [round(i,3) for i in measurement], width, label = attribute, color = ['#8fce00' if attribute == 'Safe' else '#ff1100'])
    ax2.bar_label(rects, padding = 3)
    multiplier += 1
ax2.set_ylabel('Mean values')
ax2.set_title('Numerical features')
ax2.set_xticks(x2 + (width*2.5), labels_x2)
ax2.legend(loc = 'upper right')

for attribute, measurement in features_to_plot3.items():
    offset = width * multiplier
    rects = ax3.bar(x3 + offset, [round(i,3) for i in measurement], width, label = attribute, color = ['#8fce00' if attribute == 'Safe' else '#ff1100'])
    ax3.bar_label(rects, padding = 3)
    multiplier += 1
ax3.set_ylabel('Number of True values')
ax3.set_title('Boolean features')
ax3.set_xticks(x3 + (width*4.5), labels_x3)
ax3.legend(loc = 'upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **3)REMOVING USELESS FEATURES**
#
# ---

# %% [markdown]
# We remove features that are present in a limited number of examples

# %%
data = data.drop(['numHash', 'atSymbol', 'tildeSymbol', 'domainInSubdomains', 'domainInPaths', 'httpsInHostname', 'doubleSlash'], axis=1)
url_strings = data['url']
url_types = data['type']

# %% [markdown]
# Convert target string feature to numeric

# %%
url_types = url_types.replace({'benign':1, 'malware': 0, 'phishing': 0, 'spam': 0, 'defacement': 0})

# %% [markdown]
# Separate url strings and types from features used for classification

# %%
data = data.drop(['url','type'], axis=1)

# %% [markdown]
# Convert boolean features to numeric features

# %%
data.https = data.https.replace({True: 1, False: 0})
data.ipAddress = data.ipAddress.replace({True: 1, False: 0})

# %% [markdown]
# Scaling values of training features

# %%
data
# Out:
#        numDots  subdomainLevel  pathLevel  urlLength  numDash  numUnderscore  \
# 0            2               0          2         39        0              0
# 1            2               0          1         33        0              0
# 2            1               0          3         48        1              0
# 3            1               0          0         27        0              0
# 4            2               0          1        111       12              0
# ...        ...             ...        ...        ...      ...            ...
# 19995        1               0          1         38        0              0
# 19996        2               0          1        100       15              0
# 19997        6               0          3        179        7              0
# 19998        2               1          1         33        0              0
# 19999        3               0          1         29        0              0
#
#        numPercent  numQueryComponents  numApersand  numDigits  https  \
# 0               0                   0            0          4      1
# 1               0                   0            0          0      1
# 2               0                   0            0          6      1
# 3               0                   0            0          0      1
# 4               0                   0            0         12      0
# ...           ...                 ...          ...        ...    ...
# 19995           0                   1            0          2      1
# 19996           0                   0            0          0      1
# 19997           0                   2            1         36      1
# 19998           0                   0            0          0      0
# 19999           0                   0            0         12      0
#
#        ipAddress  hostnameLength  pathLength  queryLength
# 0              0              14          17            0
# 1              0              12          14            0
# 2              0              11          30            0
# 3              0              19           1            0
# 4              0              12          92            0
# ...          ...             ...         ...          ...
# 19995          0              11           6           13
# 19996          0              17          76            0
# 19997          0              13          19          139
# 19998          0              21           5            0
# 19999          1              15           7            0
#
# [20000 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# apply MinMaxScaler on non*boolean columns
for c in data:
    if c != 'ipAddress' or c!= 'https':
       data[[c]] = scaler.fit_transform(data[[c]])

# %%
x = data.values
x.shape
# Out:
# (20000, 15)

# %% [markdown]
# **4)PRINCIPAL COMPONENT ANALYSIS**
#
# ---

# %%
from sklearn.decomposition import PCA

# %%
# Create a PCA object and fit the data
pca = PCA()
pca.fit(x)

# Plot the explained variance ratio for each component
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of components')
plt.ylabel('Explained variance ratio')
plt.show()

# %%
pca = PCA(n_components = 4)
features_x_pca = pca.fit_transform(x)

# %%
features_x_pca.shape
# Out:
# (20000, 4)

# %% [markdown]
# **5)AUTOENCODER**
#
# ---

# %%
from keras.models import Model
from keras.layers import Input, Dense

# %% [markdown]
# Generate noisy data from original data

# %%
corruption_level = 0.3

x1 = np.delete(x, [10,11], axis=1)
x_noisy = x1 + corruption_level * np.random.normal(loc=0.0, scale=1.0, size=x1.shape)
x_noisy = np.clip(x1, 0., 1.)

x_noisy = np.append(x_noisy, x[:,10:12], axis=1)

# %% [markdown]
# Define autoencoder

# %%
columns = 15
encoding_dim = 7

# Hyper parameters
batch_size = 128
nb_epoch = 100

input_x = Input(shape=(columns,))
encoded = Dense(encoding_dim, activation='relu')(input_x)
decoded = Dense(columns, activation='sigmoid')(encoded)

autoencoder = Model(inputs=input_x, outputs=decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 15)]              0
#
#  dense (Dense)               (None, 7)                 112
#
#  dense_1 (Dense)             (None, 15)                120
#
# =================================================================
# Total params: 232
# Trainable params: 232
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training autoencoder

# %%
x_train = x[0:16000, :]
x_train_noisy = x_noisy[0:16000, :]

x_test = x[16000:, :]
x_test_noisy = x_noisy[16000:, :]

autoencoder.fit(x_train_noisy, x_train,
                epochs=nb_epoch, batch_size=batch_size, shuffle=True, verbose=1,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/100
# 125/125 [==============================] - 1s 3ms/step - loss: 0.6878 - val_loss: 0.6877
# Epoch 2/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6876 - val_loss: 0.6875
# Epoch 3/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6874 - val_loss: 0.6873
# Epoch 4/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6872 - val_loss: 0.6871
# Epoch 5/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6869 - val_loss: 0.6868
# Epoch 6/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6867 - val_loss: 0.6866
# Epoch 7/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6864 - val_loss: 0.6863
# Epoch 8/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6861 - val_loss: 0.6860
# Epoch 9/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6858 - val_loss: 0.6857
# Epoch 10/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6855 - val_loss: 0.6854
# Epoch 11/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6852 - val_loss: 0.6851
# Epoch 12/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6848 - val_loss: 0.6847
# Epoch 13/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6845 - val_loss: 0.6844
# Epoch 14/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6841 - val_loss: 0.6841
# Epoch 15/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6838 - val_loss: 0.6837
# Epoch 16/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6834 - val_loss: 0.6833
# Epoch 17/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6830 - val_loss: 0.6829
# Epoch 18/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6826 - val_loss: 0.6826
# Epoch 19/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6823 - val_loss: 0.6822
# Epoch 20/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6819 - val_loss: 0.6818
# Epoch 21/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6814 - val_loss: 0.6814
# Epoch 22/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6810 - val_loss: 0.6810
# Epoch 23/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.6806 - val_loss: 0.6805
# Epoch 24/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6802 - val_loss: 0.6801
# Epoch 25/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6797 - val_loss: 0.6797
# Epoch 26/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6793 - val_loss: 0.6792
# Epoch 27/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6789 - val_loss: 0.6788
# Epoch 28/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6784 - val_loss: 0.6783
# Epoch 29/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6779 - val_loss: 0.6779
# Epoch 30/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6775 - val_loss: 0.6774
# Epoch 31/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6770 - val_loss: 0.6770
# Epoch 32/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6765 - val_loss: 0.6765
# Epoch 33/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6760 - val_loss: 0.6760
# Epoch 34/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6756 - val_loss: 0.6755
# Epoch 35/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6751 - val_loss: 0.6750
# Epoch 36/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6746 - val_loss: 0.6745
# Epoch 37/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6741 - val_loss: 0.6740
# Epoch 38/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6736 - val_loss: 0.6735
# Epoch 39/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6730 - val_loss: 0.6730
# Epoch 40/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6725 - val_loss: 0.6725
# Epoch 41/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6720 - val_loss: 0.6720
# Epoch 42/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6715 - val_loss: 0.6714
# Epoch 43/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6709 - val_loss: 0.6709
# Epoch 44/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6704 - val_loss: 0.6704
# Epoch 45/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6698 - val_loss: 0.6698
# Epoch 46/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6693 - val_loss: 0.6693
# Epoch 47/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6687 - val_loss: 0.6687
# Epoch 48/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6682 - val_loss: 0.6682
# Epoch 49/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6676 - val_loss: 0.6676
# Epoch 50/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6670 - val_loss: 0.6671
# Epoch 51/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6665 - val_loss: 0.6665
# Epoch 52/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6659 - val_loss: 0.6659
# Epoch 53/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6653 - val_loss: 0.6653
# Epoch 54/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6647 - val_loss: 0.6647
# Epoch 55/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6641 - val_loss: 0.6642
# Epoch 56/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6635 - val_loss: 0.6636
# Epoch 57/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6629 - val_loss: 0.6630
# Epoch 58/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6623 - val_loss: 0.6624
# Epoch 59/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6617 - val_loss: 0.6617
# Epoch 60/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6611 - val_loss: 0.6611
# Epoch 61/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6604 - val_loss: 0.6605
# Epoch 62/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6598 - val_loss: 0.6599
# Epoch 63/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6592 - val_loss: 0.6593
# Epoch 64/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6585 - val_loss: 0.6586
# Epoch 65/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6579 - val_loss: 0.6580
# Epoch 66/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6572 - val_loss: 0.6573
# Epoch 67/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6566 - val_loss: 0.6567
# Epoch 68/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6559 - val_loss: 0.6560
# Epoch 69/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6553 - val_loss: 0.6554
# Epoch 70/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6546 - val_loss: 0.6547
# Epoch 71/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6539 - val_loss: 0.6541
# Epoch 72/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6533 - val_loss: 0.6534
# Epoch 73/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6526 - val_loss: 0.6527
# Epoch 74/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6519 - val_loss: 0.6520
# Epoch 75/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6512 - val_loss: 0.6513
# Epoch 76/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6505 - val_loss: 0.6506
# Epoch 77/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6498 - val_loss: 0.6499
# Epoch 78/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6491 - val_loss: 0.6492
# Epoch 79/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6484 - val_loss: 0.6485
# Epoch 80/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6477 - val_loss: 0.6478
# Epoch 81/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6470 - val_loss: 0.6471
# Epoch 82/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6462 - val_loss: 0.6464
# Epoch 83/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6455 - val_loss: 0.6457
# Epoch 84/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6448 - val_loss: 0.6449
# Epoch 85/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6440 - val_loss: 0.6442
# Epoch 86/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6433 - val_loss: 0.6434
# Epoch 87/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6425 - val_loss: 0.6427
# Epoch 88/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6418 - val_loss: 0.6419
# Epoch 89/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6410 - val_loss: 0.6412
# Epoch 90/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6402 - val_loss: 0.6404
# Epoch 91/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6395 - val_loss: 0.6397
# Epoch 92/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6387 - val_loss: 0.6389
# Epoch 93/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6379 - val_loss: 0.6381
# Epoch 94/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6371 - val_loss: 0.6373
# Epoch 95/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6363 - val_loss: 0.6365
# Epoch 96/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6355 - val_loss: 0.6357
# Epoch 97/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6347 - val_loss: 0.6349
# Epoch 98/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6339 - val_loss: 0.6341
# Epoch 99/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6331 - val_loss: 0.6333
# Epoch 100/100
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6323 - val_loss: 0.6325

# %%
evaluation = autoencoder.evaluate(x_test_noisy, x_test, batch_size=batch_size, verbose=1)
print('\nSummary: Loss over the test dataset: %.2f' % (evaluation))
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6325
#
# Summary: Loss over the test dataset: 0.63

# %% [markdown]
# **6)SUPPORT VECTOR MACHINE**
#
# ---

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split

# %% [markdown]
# 1) Use features selected from PCA and decide what are the best parameters

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_x_pca, url_types.values, test_size=0.2)

# Define the parameter grid for grid search
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.1, 1, 10]
}

# %%
model_svm = SVC(kernel='rbf')

# Initialize the grid search object with 5-fold cross-validation
grid_search = GridSearchCV(clf, param_grid, cv=5)

# Fit the grid search object to the training data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=1, kernel='linear'),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.1, 1, 10]})

# %%
# Print the best parameters and mean accuracy score
print("Best parameters:", grid_search.best_params_)
print("Mean accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'C': 10, 'gamma': 0.1}
# Mean accuracy: 0.6444375

# %% [markdown]
# 2) Use features from Autoencoder

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, url_types.values, test_size=0.3, random_state=42)

# Use the encoder to transform the input data
X_train_encoded = autoencoder.predict(X_train)
X_test_encoded = autoencoder.predict(X_test)

# %%
model_svm = SVC(kernel='rbf')

# Initialize the grid search object with 5-fold cross-validation
grid_search = GridSearchCV(clf, param_grid, cv=5)

# Fit the grid search object to the training data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=1, kernel='linear'),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.1, 1, 10]})

# %%
# Print the best parameters and mean accuracy score
print("Best parameters:", grid_search.best_params_)
print("Mean accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'C': 1, 'gamma': 0.1}
# Mean accuracy: 0.775
